# %% [markdown]
# <p>Построить график гиперболического параболоида</p>
# <img src="form.png">

# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
import math
import pylab

# %%
def temp(x, y):
    x_grid, y_grid = np.meshgrid(x, y)
    z_grid = np.square(x_grid)/4 - np.square(y_grid)/9
    return x_grid, y_grid, z_grid


x = np.arange(-10, 10.5, 0.5)
y = np.arange(-10, 10.5, 0.5)
x, y, z = temp(x,y)

fig = pylab.figure()
axes = Axes3D(fig)

axes.plot_surface(x, y, z)

pylab.show()
